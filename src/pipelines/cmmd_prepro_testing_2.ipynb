# %%
import pandas as pd 

data = pd.read_csv("C:/Users/LENOVO/Desktop/umie/cmmd_data/manifest-1616439774456/metadata.csv")
data.head()
# Out:
#                                                    Series UID Collection  \
# 1.3.6.1.4.1.14519.5.2.1.1239.1759.6108236492577...       CMMD         NO
# 1.3.6.1.4.1.14519.5.2.1.1239.1759.2925608996110...       CMMD         NO
# 1.3.6.1.4.1.14519.5.2.1.1239.1759.6230064638615...       CMMD         NO
# 1.3.6.1.4.1.14519.5.2.1.1239.1759.3288256515060...       CMMD         NO
# 1.3.6.1.4.1.14519.5.2.1.1239.1759.4117124884339...       CMMD         NO
#
#                                                                        3rd Party Analysis  \
# 1.3.6.1.4.1.14519.5.2.1.1239.1759.6108236492577...  https://doi.org/10.7937/tcia.eqde4b16
# 1.3.6.1.4.1.14519.5.2.1.1239.1759.2925608996110...  https://doi.org/10.7937/tcia.eqde4b16
# 1.3.6.1.4.1.14519.5.2.1.1239.1759.6230064638615...  https://doi.org/10.7937/tcia.eqde4b16
# 1.3.6.1.4.1.14519.5.2.1.1239.1759.3288256515060...  https://doi.org/10.7937/tcia.eqde4b16
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 175 entries, 1.3.6.1.4.1.14519.5.2.1.1239.1759.610823649257711756778765445313 to 1.3.6.1.4.1.14519.5.2.1.1239.1759.160919971023875157816262316902
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Series UID            175 non-null    object
#  1   Collection            175 non-null    object
#  2   3rd Party Analysis    175 non-null    object
#  3   Data Description URI  175 non-null    object
#  4   Subject ID            175 non-null    object
#  5   Study UID             0 non-null      float64
#  6   Study Description     175 non-null    object
#  7   Study Date            0 non-null      float64
#  8   Series Description    0 non-null      float64
#  9   Manufacturer          175 non-null    object
#  10  Modality              175 non-null    object
#  11  SOP Class Name        175 non-null    object
# ...

# %%
import pandas as pd
data2 = pd.read_excel("C:/Users/LENOVO/Desktop/umie/cmmd_data/manifest-1616439774456/CMMD_clinicaldata_revision.xlsx")
data2.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\LENOVO\Desktop\umie\umie_repo\UMIE_datasets\.venv\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\importlib\__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# ...

# %%
import pandas as pd
data2 = pd.read_excel("C:/Users/LENOVO/Desktop/umie/cmmd_data/manifest-1616439774456/CMMD_clinicaldata_revision.xlsx")
data2.head()
# Out:
#        ID1 LeftRight  Age  number    abnormality classification subtype
# 0  D1-0001         R   44       2  calcification         Benign     NaN
# 1  D1-0002         L   40       2  calcification         Benign     NaN
# 2  D1-0003         L   39       2  calcification         Benign     NaN
# 3  D1-0004         L   41       2  calcification         Benign     NaN
# 4  D1-0005         R   42       2  calcification         Benign     NaN

# %%
data2 = data2[['ID1', 'abnormality']]
data2.head()
# Out:
#        ID1    abnormality
# 0  D1-0001  calcification
# 1  D1-0002  calcification
# 2  D1-0003  calcification
# 3  D1-0004  calcification
# 4  D1-0005  calcification

# %%
data2['abnormality'][data2['ID1']=='D1-0001']
# Out:
# 0    calcification
# Name: abnormality, dtype: object

# %%
data2.head()
# Out:
#        ID1    abnormality
# 0  D1-0001  calcification
# 1  D1-0002  calcification
# 2  D1-0003  calcification
# 3  D1-0004  calcification
# 4  D1-0005  calcification

# %%
data2.set_index('ID1', inplace=True)
data2.head()
# Out:
#            abnormality
# ID1
# D1-0001  calcification
# D1-0002  calcification
# D1-0003  calcification
# D1-0004  calcification
# D1-0005  calcification

# %%
data2.loc['D1-0001']
# Out:
# abnormality    calcification
# Name: D1-0001, dtype: object

# %%
if (data2.loc['D1-0001'] == 'calcification').bool():
    print("Yes, it's calcification.")
# Out:
# Yes, it's calcification.
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_12772\750399904.py:1: FutureWarning: Series.bool is now deprecated and will be removed in future version of pandas
#   if (data2.loc['D1-0001'] == 'calcification').bool():

# %%
import pandas as pd 
data2 = pd.read_excel("C:/Users/LENOVO/Desktop/umie/cmmd_data/manifest-1616439774456/CMMD_clinicaldata_revision.xlsx")
data2.head()
# Out:
#        ID1 LeftRight  Age  number    abnormality classification subtype
# 0  D1-0001         R   44       2  calcification         Benign     NaN
# 1  D1-0002         L   40       2  calcification         Benign     NaN
# 2  D1-0003         L   39       2  calcification         Benign     NaN
# 3  D1-0004         L   41       2  calcification         Benign     NaN
# 4  D1-0005         R   42       2  calcification         Benign     NaN

# %%
data2=data2[['ID1', 'abnormality', "classification"]]
data2.head()
# Out:
#        ID1    abnormality classification
# 0  D1-0001  calcification         Benign
# 1  D1-0002  calcification         Benign
# 2  D1-0003  calcification         Benign
# 3  D1-0004  calcification         Benign
# 4  D1-0005  calcification         Benign

# %%
data2.rename(columns={'ID1':'id', 'abnormality':'label1', 'classification':'label2'},inplace=True)
data2.head()
# Out:
#         id         label1  label2
# 0  D1-0001  calcification  Benign
# 1  D1-0002  calcification  Benign
# 2  D1-0003  calcification  Benign
# 3  D1-0004  calcification  Benign
# 4  D1-0005  calcification  Benign

# %%
data2[data2['id']=='D1-0001'].values[0][2]
# Out:
# 'Benign'

# %%
type(data2[data2['id']=='D1-0001'].values[0][2])
# Out:
# str

# %%
import os 

path = "C:/Users/LENOVO/Desktop/umie/cmmd_data/manifest-1616439774456/CMMD/D1-0001/07-18-2010-NA-NA-79377/1.000000-NA-70244/1-2.dcm"
s = os.path.basename(os.path.dirname(os.path.dirname(os.path.dirname(path))))
print(s)
print(type(s))
# Out:
# D1-0001
# <class 'str'>

# %%
if s == 'D1-0001': 
    print('Yes.')
# Out:
# Yes.

# %%
img_path_label = s 
label = data2[data2['id']==img_path_label].values[0][1]
print(label)
# Out:
# calcification

# %%
label = data2[data2['id']=='D1-0563'].values[0][1]
print(label)
# Out:
# both

# %%
a = 'aaaa'
b = 'bbbb'
c= [a, b]
print(c)
# Out:
# ['aaaa', 'bbbb']

# %%
import matplotlib.pyplot as plt 
import pydicom 

path = r"C:\Users\LENOVO\Desktop\umie\cmmd_test_data\manifest_00001\CMMD\D1-0002\07-18-2010-NA-NA-49231\1.000000-NA-45313\1-1.dcm"
ds = pydicom.dcmread(path)

plt.imshow(ds.pixel_array, cmap=plt.cm.bone)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 import pydicom
#       4 path = r"C:\Users\LENOVO\Desktop\umie\cmmd_test_data\manifest_00001\CMMD\D1-0002\07-18-2010-NA-NA-49231\1.000000-NA-45313\1-1.dcm"
#       5 ds = pydicom.dcmread(path)
#
# ModuleNotFoundError: No module named 'pydicom'

# %%
import pydicom
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pydicom
#
# ModuleNotFoundError: No module named 'pydicom'

# %%
import pydicom 
import matplotlib.pyplot as plt

path = 'C:/Users/LENOVO/Desktop/1-1.dcm'
ds = pydicom.dcmread(path)

plt.imshow(ds.pixel_array, cmap=plt.cm.bone)

# %%
import os 

img_path = r"C:\Users\LENOVO\Desktop\umie\cmmd_test_data\manifest_00001\CMMD\D1-0002\07-18-2010-NA-NA-49231\1.000000-NA-45313\1-1.dcm"
img_id = os.path.basename(img_path)
img_id
# Out:
# '1-1.dcm'

# %%
####

# %%
path = "C:/Users/LENOVO/Desktop/umie/cmmd_data/manifest-1616439774456/1-2.dcm"

# %%
import os 

img_id = os.path.basename(path)
img_id = os.path.splitext(img_id)[0].split("-")[1]
img_id
# Out:
# '2'

# %%
separator = '-'
maxsplit = -1
index = -1
os.path.basename(path).rsplit(separator, maxsplit=maxsplit)[index]
# Out:
# '2.dcm'
